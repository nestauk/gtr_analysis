# %% [markdown]
# # Geocoding Organisations
#
# For a number of planned analyses, we require the latitude and longitude of the organisations in the data, not just their names and addresses. To do this we will first use a geocoding service to identify lat lng from address strings.

# %%
import pickle
import ratelim
import json
import numpy as np
import os
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

from geopy.geocoders import GoogleV3
from ipywidgets import FloatProgress
from IPython.display import display

key = os.environ.get('GOOGLE_MAPS_KEY')

# %%
# Google geocoder
geocoder = GoogleV3(api_key=key)

# %%
# Read in config file with DB params
with open('../scripts/config.json') as f:
    conf = json.load(f)
    
# Define a connection string
conn_string = 'host={} dbname={} user={} password={}'.format(conf.get('host'),
                                                             conf.get('database'),
                                                             conf.get('user'),
                                                             conf.get('passw'))

# Create a connection object
conn = psycopg2.connect(conn_string)

# SQL string that unpacks nested JSON arrays
sql_str = """
SELECT id, name, addresses from gtr.organisations;
"""

# chunksize returns an iterator that reads chunk number of rows at a time
df = pd.read_sql(sql_str,
                 conn)

# %%
def country(x):
    try:
        return x.get('address', None)[0].get('country', None).lower()
    except:
        return None

# %%
# API rate limits with billing enabled
@ratelim.greedy(5, 1)
def geocode(address_dict):
    # Get the list out of the dict
    address_list = address_dict['address']

    # If no country need to assume UK
    if address_list and address_list[0].get('country', 'uk').lower() in uk_names:
        try:
            pc = address_dict['address'][0]['postCode']
            return geocoder.geocode(pc)
        except:
            address = address_str(address_dict)
            if address:
                return geocoder.geocode(address)
            else:
                return None
    else:
        address = address_str(address_dict, uk=False)
        if address:
            g = geocoder.geocode(address)
        else:
            return None

# %%
def get_add_part(address_entry, part):
    try:
        return address_entry['address'][0].get('{}'.format(part), None)
    except:
        return None

# %%
def postcode(address_entry):
    return get_add_part(address_entry, 'postcode')

# %%
def country(address_entry):
    c = get_add_part(address_entry, 'country')
    if c == None:
        return 'uk'
    else:
        return c.lower()

# %%
def line1(address_entry):
    return get_add_part(address_entry, 'line1')

# %%
def address_str(address_dict, uk=True):
    
    uk_address_keys = [
    'line1',
    'line2',
    'line3',
    'county',
    'postCode',
    ]
    
    other_address_keys = [
        'line1',
        'line2',
        'line3',
        'line4',
        'line5'
        'county',
        'country',
    ]
    
    if uk:
        address_keys = uk_address_keys
    else:
        address_keys = other_address_keys
    
    l = []
    address_list = address_dict.get('address', None)
    if address_list is None:
        return None
    try:
        if address_list[0] is not None:
            [l.append(address_list[0][key]) if key in address_keys else '' for key in address_list[0]]            
    except:
        return None
    
    return ", ".join(l)

# %%
def check_address(address_dict):
    address_list = address_dict.get('address', None)
    if address_list is None:
        return False
    try:
        if address_list[0] is not None:
            return True
    except:
        return False

# %%
# Function to get tuple by position, returning
# None where there isn't a valid entry
def get_tuple_value(x, pos):
    try:
        return x[pos]
    except TypeError:
        return None

# %%
# All the ways people put down UK in the country field
uk_names = ['united kingdom',
 'uk',
 'wales',
 'england',
 'scotland',
 'united kingom',
 'northern ireland',
 'united kindgom',
 'buckinghamshire',
 'yorkshire',
 'london',
 'u.k.',
 'united ,kingdom',
 'berkshire',
 'jersey',
 ' united kingdom',
 'u.k',
 '|united kingdom']

# %%
df['postcode'] = df.addresses.map(postcode)
n_postcodes = df.postcode.count()
n_no_postcodes = len(df.postcode) - n_postcodes
print('{} organisations with postcodes, {} without'.format(n_postcodes, n_no_postcodes))
# Out:
# 18266 organisations with postcodes, 7299 without

# %% [markdown]
# We will be unable to geocode 7,299 organisations by using only a postcode in the geocode request. Lets check how many of those without postcodes, also lack other address details. For instance, organisations from outside the UK would lack a postcode, but can still be geocoded using a string lookup.

# %%
# Full dataframe check
df.addresses.map(check_address).value_counts()
# Out:
# True     21205
# False     4360
# Name: addresses, dtype: int64

# %%
# Subset of those without postcodes
df[df.postcode.isnull()].addresses.map(check_address).value_counts()
# Out:
# False    4360
# True     2939
# Name: addresses, dtype: int64

# %% [markdown]
# Of the 7,299 organisations without a postcode, 4,360 also have no address data. This leaves 2,939 organisations with no postcode but some data in the address field. Therefore the maximum number of geocoded organisations will be 21,205. When geocoding, we will default to the use of a postcode where possible, and fallback to an address string where a postcode isn't present.

# %%
"""latlng = []
num_addresses = df.addresses.shape[0]
f = FloatProgress(min=0, max=num_addresses)
display(f)

for address in df.addresses:
    g = geocode(address)
    try:
        latlng.append((g.latitude, g.longitude))
    except AttributeError:
        latlng.append(None)
    f.value += 1
"""

# %%
# Save as a pickled object
pickle.dump( latlng, open( "latlng.p", "wb" ) )

# %%
df_latlng = pd.DataFrame(np.asarray(latlng))

# %%
df_result = df.merge(df_latlng, left_index=True, right_index=True)
df_result.rename(columns={0: 'latlng'}, inplace=True)
df_result = df_result[df_result.latlng.notnull()]
df_result[['lat', 'lng']] = df_result.latlng.apply(pd.Series)
df_result.drop(['postcode', 'addresses', 'latlng'], axis=1, inplace=True)

# %%
df_result
# Out:
#                                          id  \
# 0      BAB46AB6-90FC-4145-B885-0153BEA15A73
# 2      BCD9069A-6739-4039-86DB-042CB13254CB
# 3      B69FACF5-5AB9-4D97-88CD-0A38C32935FF
# 4      B76FE143-1E07-40B0-8932-028207296A78
# 5      B80095E4-9D0F-4398-8A0E-07EB418EFFF6
# 6      B966BD7A-F468-4C74-A694-0842CB8F884F
# 8      BA32CA96-1A26-415F-B3B2-0DC1DDFCE74F
# 9      BA59F886-138D-41EB-B9B1-0C79E45C61D3
# 10     BA7D8BB2-4B17-4D57-AC78-001BA0F40F77
# 11     C059DB15-1836-430B-A993-0759206ABBB8
# 13     C066B655-E1BA-447A-A432-01FB6725E320
# 14     C2B3EE68-0D08-4321-964A-02108F67A3F8
# 15     C30DF86F-9DD8-4A78-97BA-067527E5E391
# 18     C42E852D-5D31-4DE8-8E91-04CF66DA9DE2
# 19     C59C7E94-5DD5-4DCA-8586-09189A61F279
# 20     C8A76B9E-4F39-490B-BCCF-009F592A756C
# 21     C9069C42-693D-4C9C-B66B-0D968C7277AA
# 22     C9424089-9FC7-4BD3-8C9A-0E38B885E2CE
# 25559             Transport for Greater Manchester  53.478372   -2.232950
# 25560                Luxfer Gas Cyclinders Limited  53.474040   -2.286319
# 25561   May Barn Horticultural Consultancy Limited  53.031839   -2.529046
# 25562                    ATG UV Technology Limited  53.537295   -2.679350
# 25563                       James Dewhurst Limited  53.790529   -2.348961
# 25564                    Biocarbon Engineering Ltd  51.747988   -1.232856
#
# [20219 rows x 4 columns]

# %%
engine = create_engine('postgresql://{}:{}@{}/{}'.format(conf.get('user'),
                                                         conf.get('passw'),
                                                         conf.get('host'),
                                                         conf.get('database')))

conn = engine.connect()

# %%
df_result.to_sql('orgs_latlng',
                 conn,
                 schema='gtr',
                 if_exists='replace',
                 index=False)

# %% [markdown]
# # From here delete

# %%
latlng = pickle.load(open('latlng.p', 'rb'))

# %%
g = geocoder.geocode("SG8 7RE")
g
# Out:
# Location(Church St, Thriplow, Royston, Cambridgeshire SG8 7RE, UK, (52.0997269, 0.1046752, 0.0))

# %%
df_result = df.merge(df_latlng, left_index=True, right_index=True)
df_result.rename(columns={0: 'latlng'}, inplace=True)

# %%
df_result[~df_result.country.isin(uk_names)].country.unique()
# Out:
# array(['china', 'netherlands', 'australia', 'canada', 'austria', 'ireland',
#        'japan', 'norway', 'brazil', 'sri lanka', 'switzerland', 'france',
#        'united states', 'kenya', 'new zealand',
#        'taiwan, province of china', 'zimbabwe', 'portugal', 'germany',
#        'estonia', 'india', 'russian federation', 'singapore', 'nigeria',
#        'spain', 'belgium', 'poland', 'italy', 'south africa', 'ethiopia',
#        'bolivia, plurinational state of', 'denmark', 'uganda', 'viet nam',
#        'kyrgyzstan', 'malawi', 'malaysia', 'mexico', 'argentina',
#        'hungary', 'el salvador', 'bangladesh', 'greece', 'ukraine',
#        'cambodia', 'chile', 'peru', 'thailand', 'mozambique', 'ghana',
#        'israel', 'cuba', 'sierra leone', 'morocco', 'hong kong', 'zambia',
#        'cameroon', 'tanzania, united republic of', 'sweden', 'iceland',
#        'kazakhstan', 'korea, republic of', 'bosnia and herzegovina',
#        'ecuador', 'finland', 'croatia', 'saudi arabia', 'madagascar',
#        'slovenia', 'mali', 'philippines', 'usa', 'czech republic',
#        'indonesia', 'venezuela, bolivarian republic of', 'colombia',
#        'romania', 'egypt', 'turkey', 'albania',
#        'iran, islamic republic of', 'jamaica', 'burundi', 'slovakia',
#        'georgia', 'syrian arab republic', 'united company', 'nepal',
#        'burkina faso', 'macao', 'solomon islands', 'outside uk',
#        'costa rica', 'trinidad and tobago', 'congo',
#        'united arab emirates', 'new caledonia', 'palestine, state of',
#        'the netherlands', 'namibia', 'yemen', 'sudan', 'fiji', 'rwanda',
#        'saint lucia', 'gabon', 'gambia', 'niger', 'greenland',
#        'montserrat', 'qatar', 'serbia', 'senegal', 'azerbaijan',
#        'pakistan', 'yugoslavia', 'panama', 'lebanon', 'myanmar', 'sn2 2qw'], dtype=object)

# %%
df_result['country'] = df.addresses.map(country)
df_result['line1'] = df_result.addresses.map(line1)

# %%
df_other_countries = df_result[~df_result.country.map(lambda x: x.lower()).isin(uk_names)]

# %%
usa = ['usa', 'united states']
df_usa = df_other_countries[df_other_countries['country'].isin(usa)]

# %%
num_addresses = df_usa.iloc[166:].addresses.shape[0]
f = FloatProgress(min=0, max=num_addresses)
display(f)

for address in df_usa.iloc[166:].addresses:
    g = geocode(address)
    try:
        us_latlng.append((g.latitude, g.longitude))
    except AttributeError:
        us_latlng.append(None)
    f.value += 1

# %%
df_usa.reset_index(drop=True, inplace=True)
df_usa.drop('latlng', axis=1, inplace=True)
df_usa = df_usa.merge(df_latlng, left_index=True, right_index=True)
df_usa.rename(columns={0: 'latlng'}, inplace=True)
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_usa
# Out:
#                                        id  \
# 0    2795AB81-FD33-413D-BBE4-127D1ACE6210
# 1    55044D17-2C14-4D68-BED1-119271B476B4
# 2    58E3A7F8-5B1E-48D2-BDC5-0E835B3FA948
# 3    5FC4C032-4778-4A82-95CD-13F5897F599B
# 4    527728F1-2397-4BCC-AA10-1137F55A1D9E
# 5    1003BE2C-9E2D-4A5D-A13D-058587870722
# 6    B3C4BA7F-0E8E-4F2F-88C2-04277E328EB0
# 7    AFE5C6FD-3500-44F6-B100-184B5F2FD0D7
# 8    C1DA4809-2264-4894-9C3C-190942EACF3C
# 9    B8480401-8DDE-472E-9BFB-13DEC29BD816
# 10   1B56BE39-25BE-4A95-9BAA-5F7EC425A638
# 11   FB74D388-22C0-4DAB-9D15-BFF9CFA45E4B
# 12   FC9ED2E5-3AE9-4CB4-AD0C-B8953F01D45C
# 13   39313FCF-0990-4E36-B136-80AC7830128F
# 14   F25BC0C5-5284-441F-B79F-A61707946CA0
# 15   A1067C91-D7E3-4CBC-A671-583F17B73185
# 16   99254C6D-7CCC-48F0-B118-7E25FF247891
# 17   93589381-05D5-494F-875F-5DCE3BA590C0
# 18   65E2BD5E-63AB-4245-BB34-8FF0EBA452A1
# 19   6D30F26F-5158-46AA-AE3E-9D9EF1395FD8
# 20   7266DA07-C495-49A1-B0A3-7C4C39A58D6A
# 21   729C9072-B04E-45DD-A0B1-74028C36235E
# 22   736985B4-EC0B-49E5-B8B0-7C91DBCFB55D
# 23   5810877C-CDDA-4FFA-901C-6A9055CF8735
# 24   4B4BAD27-8E4B-4D62-B7FB-6A3382E633AF
# 25   E6756F63-3FA1-4DD9-8FFB-67C6EB0C4E90
# 26   7852EBBB-C808-481F-8DAE-65F3E57E48CD
# 27   88B1E177-B3F4-421A-85E1-683228DE3D70
# 28   88D88D16-DC00-4266-AB15-99A0172E1310
# 29   A486D494-6ED1-4FFC-A58E-804F8D5FDB7F
# ..                                    ...
# 569  483ABDB0-1754-410A-8FB0-A9A5CB2D0538
# 570  520A7BCF-C90B-4FC1-A771-68E66D8A2810
# 571  72C63E68-FE68-4BE1-B650-D43E6DB3B0AF
# 582   Cold Regions Research & Engineering Lab
# 583               Boeing Aerospace UK Limited
# 584                    Janssen Pharmaceutical
# 585                   Combimatrix Corporation
# 586           Harvard School of Public Health
# 587               University of New Hampshire
# 588       Extreme Science & Eng Discovery Env
# 589                      Dow Chemical Company
# 590                     University of Vermont
# 591                            Zyvex Labs LLC
# 592                           Rice University
# 593                            Morgan Stanley
# 594                University of Rhode Island
# 595                             Teragrid NCSA
# 596                                 Datacolor
# 597          University of Texas at Arlington
# 598               Honeywell International Inc
#
#                                              addresses        country  \
# 0    {'address': [{'line4': 'Chicago', 'line1': 'Un...  united states
# 1    {'address': [{'line4': 'Miami', 'line1': 'Rose...  united states
# 2    {'address': [{'line4': 'New York 14580', 'line...  united states
# 3    {'address': [{'line1': '5885 Hollis Street', '...  united states
# 4    {'address': [{'line1': '2226 Central Ave.,', '...  united states
# 5    {'address': [{'line4': 'Auburn', 'line1': '301...  united states
# 6    {'address': [{'line1': '1601 Connecticut Ave N...  united states
# 7    {'address': [{'line4': 'Redmond', 'line1': 'On...  united states
# 8    {'address': [{'line1': 'Mississippi State Univ...  united states
# 9    {'address': [{'line4': 'Baton Rouge', 'line1':...  united states
# 10   {'address': [{'line1': '380 Park Place Blvd.',...  united states
# 11   {'address': [{'line4': 'Greenville', 'line1': ...  united states
# 12   {'address': [{'line4': 'Birmingham', 'line1': ...  united states
# 13   {'address': [{'line1': '460 West 34th Street',...  united states
# 14   {'address': [{'line4': 'Los Angeles', 'line1':...  united states
# 15   {'address': [{'line4': 'Wilmington', 'line1': ...  united states
# 16   {'address': [{'line1': '340 Quinnipiac Street'...  united states
# 17   {'address': [{'line4': 'West Chester', 'line1'...  united states
# 18   {'address': [{'line4': 'Framingham', 'line1': ...  united states
# 19   {'address': [{'line4': 'Batavia', 'line1': 'Fe...  united states
# 20   {'address': [{'line1': '4th Floor', 'id': '227...  united states
# 21   {'address': [{'line4': 'Poughkeepsie', 'line1'...  united states
# 22   {'address': [{'line4': 'Syracuse', 'line1': '1...  united states
# 23   {'address': [{'line4': 'Massachusetts', 'line1...  united states
# 24   {'address': [{'line4': 'Boston', 'line1': '44 ...  united states
# 25   {'address': [{'line1': '110 Technology Center ...  united states
# 26   {'address': [{'line1': '420 Blossom Hill Road'...  united states
# 27   {'address': [{'line4': 'Tempe', 'line1': 'PO B...  united states
# 28   {'address': [{'line1': '9000 Plymouth Avenue N...  united states
# 29   {'address': [{'line1': 'ConAgra Drive', 'id': ...  united states
# ..                                                 ...            ...
# 569  {'address': [{'line4': 'Missoula', 'line1': '3...  united states
# 570  {'address': [{'line1': '420 College Ave', 'id'...  united states
# 571  {'address': [{'line4': 'Minneapolis', 'line1':...  united states
# 572  {'address': [{'line4': 'Chicago', 'line1': '10...  united states
# 573  {'address': [{'line1': 'San Luis Obispo', 'cou...  united states
# 574  {'address': [{'line4': 'Mclean', 'line1': '171...  united states
# 575  {'address': [{'line4': 'Ruston', 'line1': 'Col...  united states
# 576  {'address': [{'line1': '1329 Moffett Park Driv...  united states
# 577  {'address': [{'line1': '1349 West Peachtree St...            usa
# 578  {'address': [{'line1': '5621 Arapahoe Ave, Sui...  united states
# 579  {'address': [{'line1': '33 Commercial Street',...  united states
# 580  {'address': [{'line1': '100 Glenborough Drive'...  united states
# 581  {'address': [{'line4': 'Queens', 'line1': '65-...  united states
# 582  {'address': [{'line4': 'New Hampshire', 'line1...  united states
# 583  {'address': [{'line1': 'P.O. Box 516', 'id': '...            usa
# 584  {'address': [{'line1': '1125 Trenton_Harbourto...  united states
# 585  {'address': [{'line4': 'Mukitteo', 'line1': '6...  united states
# 586  {'address': [{'line4': 'Boston', 'line1': 'Har...  united states
# 587  {'address': [{'line4': 'Durham', 'line1': 'Uni...  united states
# 588  {'address': [{'line1': 'University of Illinois...  united states
# 589  {'address': [{'line1': 'Corporate Headquarters...  united states
# 590  {'address': [{'line4': 'Burlington', 'line1': ...  united states
# 591  {'address': [{'line1': '1321 North Plano Road'...  united states
# 592  {'address': [{'line4': 'Houston', 'line1': 'Ri...  united states
# 593  {'address': [{'line4': 'New York', 'line1': '1...  united states
# 594  {'address': [{'line4': 'Kingston', 'line1': 'U...  united states
# 595  {'address': [{'line4': 'Champaign', 'line1': '...  united states
# 596  {'address': [{'line1': '5 Princess Road', 'id'...  united states
# 597  {'address': [{'line1': '701 s.Nedderman Drive'...  united states
# 598  {'address': [{'line4': 'Morristown', 'line1': ...  united states
#
#                                         line1  \
# 0                       University of Chicago
# 1       Rosentiel Sch of Marine & Atmospheric
# 2                           800 Phillips Road
# 3                          5885 Hollis Street
# 4                          2226 Central Ave.,
# 5                           301 Funchess hall
# 6          1601 Connecticut Ave NW, Suite 200
# 7                           One Microsoft Way
# 8                Mississippi State University
# 9                  Louisiana State University
# 10                       380 Park Place Blvd.
# 11                   East Carolina University
# 12                      1720 2nd Avenue South
# 13                       460 West 34th Street
# 14                        405 Hillgard Avenue
# 15     North Carolina University - Wilmington
# 16                      340 Quinnipiac Street
# 17                                Synthes Inc
# 18                          One Mountain Road
# 19                                   Fermilab
# 20                                  4th Floor
# 21                         124 Raymond Avenue
# 22                           1 Forestry Drive
# 23                        202 Burlington Road
# 24                           44 Binney Street
# 25             110 Technology Center Building
# 26                      420 Blossom Hill Road
# 27                              PO Box 875603
# 28                 9000 Plymouth Avenue North
# 29                              ConAgra Drive
# ..                                        ...
# 569                           32 Campus Drive
# 570                           420 College Ave
# 571               St Anthony Falls Laboratory
# 572                        10 West 3st Street
# 573                           San Luis Obispo
# 574                           1710 SAIC Drive
# 575          College of Engineering & Science
# 576                   1329 Moffett Park Drive
# 577  1349 West Peachtree Street\r\nSuite 2000
# 578                5621 Arapahoe Ave, Suite A
# 579                      33 Commercial Street
# 580                     100 Glenborough Drive
# 581                      65-30 Kissena Blvd.|
# 582   Cold Regions Research & Engineering Lab
# 583                              P.O. Box 516
# 584              1125 Trenton_Harbourton Road
# 585              6500 Harbour Heights Parkway
# 586           Harvard School of Public Health
# 587               University of New Hampshire
# 588  University of Illinois, Urbana-Champaign
# 589                    Corporate Headquarters
# 590                     University of Vermont
# 591                     1321 North Plano Road
# 592                           Rice University
# 593                             1585 Broadway
# 594                University of Rhode Island
# 595  University of Illinois at Ubana-Champaig
# 596                           5 Princess Road
# 597                     701 s.Nedderman Drive
# 598                         101 Columbia Road
#
#                                 latlng
# 0            (41.8150541, -87.6018039)
# 1            (25.7326204, -80.1626698)
# 2            (43.2228451, -77.4170792)
# 3           (37.8405026, -122.2899738)
# 4              (34.48994, -93.0586689)
# 5            (32.6000095, -85.4823262)
# 6     (38.9113709, -77.04408049999999)
# 7           (47.6393096, -122.1283559)
# 8            (33.4555279, -88.7903868)
# 9            (30.4539947, -91.1848407)
# 10          (37.9376529, -121.2925971)
# 11    (34.85261759999999, -82.3940104)
# 12           (33.5095707, -86.8067248)
# 13           (40.7541045, -73.9989178)
# 14          (34.0522342, -118.2436849)
# 15           (34.2252905, -77.8745331)
# 16           (41.4560989, -72.8343502)
# 17           (39.9606643, -75.6054882)
# 18           (42.3032634, -71.4806898)
# 19    (41.8403204, -88.23273030000001)
# 20          (39.7180262, -104.9875017)
# 21    (41.6804089, -73.89611099999999)
# 22     (43.034718, -76.13635459999999)
# 23           (42.5049006, -71.2365435)
# 24            (42.337689, -71.1073274)
# 25            (42.159436, -71.0631451)
# 26          (37.2352811, -121.9695714)
# 27          (33.4255104, -111.9400054)
# 28    (44.9942043, -93.39259349999999)
# 29     (41.254839, -95.92605449999999)
# ..                                 ...
# 569          (46.8605765, -113.982128)
# 570         (33.5891792, -102.3675774)
# 571           (44.977753, -93.2650108)
# 572          (41.8781136, -87.6297982)
# 573         (35.3042949, -120.6657288)
# 574           (38.922607, -77.2340229)
# 575   (32.5232053, -92.63792699999999)
# 576         (37.4109453, -122.0044173)
# 577   (32.9975097, -82.41670769999999)
# 578           (40.017275, -105.222726)
# 579           (42.055164, -71.2467456)
# 580          (29.9517221, -95.4196309)
# 581          (40.7362342, -73.8160795)
# 582    (52.3758916, 9.732010400000002)
# 583             (37.09024, -95.712891)
# 584           (40.292916, -74.8471603)
# 585  (47.89710059999999, -122.3218093)
# 586   (42.3355139, -71.10229819999999)
# 587           (35.9940329, -78.898619)
# 588          (40.1093094, -88.2283887)
# 589                               None
# 590            (44.476765, -73.201539)
# 591          (32.9648766, -96.7008613)
# 592          (29.7164461, -95.3992521)
# 593          (40.7599901, -73.9855511)
# 594          (41.4852985, -71.5255856)
# 595          (40.1164204, -88.2433829)
# 596            (40.283264, -74.707555)
# 597          (32.7292595, -97.1149674)
# 598               (40.7913, -74.44328)
#
# [599 rows x 6 columns]

# %%
df_usa.to_sql('orgs_latlng_us',
              conn,
              schema='gtr',
              if_exists='replace',
              index=False)
